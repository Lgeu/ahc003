# %%
# !conda install -c conda-forge optuna -y
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/nagis/anaconda3
#
#   added / updated specs:
#     - optuna
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alembic-1.6.3              |     pyhd8ed1ab_0         114 KB  conda-forge
#     cliff-3.7.0                |     pyhd8ed1ab_1          54 KB  conda-forge
#     cmaes-0.8.2                |     pyh44b312d_0          16 KB  conda-forge
#     cmd2-1.5.0                 |   py38h578d9bd_0         181 KB  conda-forge
#     colorlog-5.0.1             |   py38h578d9bd_0          15 KB  conda-forge
#     conda-4.10.1               |   py38h578d9bd_0         3.1 MB  conda-forge
# ...

# %%
import re
import sys
from time import sleep
from pprint import pprint
from functools import partial

import optuna
try:
    import pandas as pd
except:
    pass


FILENAME = "main.cpp"

# %%
# テストケース生成

SEED = 0
N_TESTCASES = 100
# !seq {SEED} {SEED+N_TESTCASES-1} > seeds.txt && cargo run --release --manifest-path ../tools/Cargo.toml --bin gen seeds.txt
# !ls in
# Out:
#   File "<ipython-input-81-2497ce49c432>", line 6
#     ls in
#          ^
# SyntaxError: invalid syntax

# %%
# !cp ../main.cpp ./

# %%
# !g++ {FILENAME} -std=gnu++17 -Wall -Wextra -O2 -DONLINE_JUDGE -o {FILENAME}.out
# Out:
# main.cpp:398: warning: ignoring #pragma warning  [-Wunknown-pragmas]
#   398 | #pragma warning( disable : 4146 )
#       |
# main.cpp: In member function ‘void State::Update(const double&)’:
# main.cpp:979:28: warning: unused parameter ‘progress_rate’ [-Wunused-parameter]
#   979 |  void Update(const double& progress_rate) {
#       |              ~~~~~~~~~~~~~~^~~~~~~~~~~~~
# main.cpp: In member function ‘void State::CalcScoreNaive(const double&)’:
# main.cpp:1119:36: warning: unused parameter ‘progress_rate’ [-Wunused-parameter]
#  1119 |  void CalcScoreNaive(const double& progress_rate = 1.0) {
#       |                      ~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~
# main.cpp: In static member function ‘static double Estimator::Schedule(const double&)’:
# main.cpp:1205:39: warning: unused parameter ‘r’ [-Wunused-parameter]
#  1205 |  static double Schedule(const double& r) {
#       |                         ~~~~~~~~~~~~~~^
# main.cpp: In member function ‘void Explorer::Step()’:
# ...

# %%
# !g++ {FILENAME} -std=gnu++17 -Wall -Wextra -O2 -o {FILENAME}.debug.out -g
# Out:
# main.cpp:398: warning: ignoring #pragma warning  [-Wunknown-pragmas]
#   398 | #pragma warning( disable : 4146 )
#       |
# main.cpp: In member function ‘void State::Update(const double&)’:
# main.cpp:979:28: warning: unused parameter ‘progress_rate’ [-Wunused-parameter]
#   979 |  void Update(const double& progress_rate) {
#       |              ~~~~~~~~~~~~~~^~~~~~~~~~~~~
# main.cpp: In member function ‘void State::CalcScoreNaive(const double&)’:
# main.cpp:1119:36: warning: unused parameter ‘progress_rate’ [-Wunused-parameter]
#  1119 |  void CalcScoreNaive(const double& progress_rate = 1.0) {
#       |                      ~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~
# main.cpp: In static member function ‘static double Estimator::Schedule(const double&)’:
# main.cpp:1205:39: warning: unused parameter ‘r’ [-Wunused-parameter]
#  1205 |  static double Schedule(const double& r) {
#       |                         ~~~~~~~~~~~~~~^
# main.cpp: In member function ‘void Explorer::Step()’:
# ...

# %%
#run params ... < in/0000.txt
#!gdb ./{FILENAME}.debug.out

# %%
#!./{FILENAME}.debug.out < in/0000.txt

# %%
# %%time
# !cargo run --release --manifest-path ../tools/Cargo.toml --bin tester in/0000.txt $(pwd)/{FILENAME}.out | tee out.txt
# Out:
#     Finished release [optimized] target(s) in 0.01s
#      Running `/home/nagis/ahc003/tools/target/release/tester in/0000.txt /home/nagis/ahc003/exp001/main.cpp.out`
# DDDDDDDDDDDDDDDDDDDDDDLLLLLLLLLLLLLLLLLLLL
# DDDDDDDDDDDDRRRR
# LLLLLLLLLUUUUUUUU
# UUUUUUUUUUUUURRRRRRRRRRRRRR
# UUUUUUURRRRRRRRRRRRR
# RDDDDDDDDDDDDDDDDDDDDD
# RRRRRRRRRRRUUUUUUUU
# RDDDDDDDDDDD
# UUUUUUUUUUUUUUURRRRRRRRRRRRRR
# ULLLLLLLLLLLL
# RDDDDDDDDDDDDDDDDDDDDD
# DDDDDLLLLLLLLLL
# DDDDDDDDDDDDDDDDDDDDDDDLL
# UUUUUUUUUUU
# LDDDDDDDDDDDDD
# RRRRRRRUUUUUUUUUUUUUUUUUUUUUUUUUUU
# RRRRRRRRRRRDDDDDDDDDDDDDDDDDDDD
# DDDDDDDDDRRRRRR
# DDDDDDDDDDDDDDDDDDDDDLLLLLLLLLLLLLLLLLLLLLLLLLLLL
# RRRRRRRRRRRDDDD
# UUUUUUUUUUUUUUUUUUUUURRRRRRRRRRRRRRRRRR
# DDDDDDDDDDDDDDDLL
# DRRRRRRRRRRRRR
# RUUUUUUUUUUUUUUU
# LLLLLLLLLLLLLLLLLLDDDDDDDD
# UUUUUUUUUUUUUUURRRRRRRRRR
# DDDDDDDDDDDDDDDDDLLLLLL
# LLLLLLLLLLLLDDDDDDDDDDDD
# LLLLLLLLLLLLDDDDDD
# RRRRRRRRRRRRRRRRRRRRRUUUUUUUUUU
# LLLLLLLLLLLLLLLLLLUUUUUUUU
# UUUUUUUUUUUUUULL
# ...

# %%
cat in/0000.txt
# Out:
# 4339 5263 5520 4976 3950 4280 5488 4671 4468 3954 5497 3810 5123 4282 4019 4068 4563 4864 4693 4565 4924 5533 5036 5251 3854 4712 4972 5117 4146
# 7639 6966 8523 7968 7450 8306 8260 7674 7876 7974 7019 6793 7711 7452 7868 7599 8752 6880 6934 7315 8448 8241 8732 7598 8178 8033 8031 7570 7463
# 7893 7742 7518 7123 7538 6917 6450 7573 7844 6878 6348 7099 7552 7104 7348 6228 7634 8014 7988 6703 6519 6776 6144 6840 6395 6941 8147 6618 6731
# 7052 6099 6805 7622 6558 7681 6739 6761 5910 6396 6873 7225 6931 6478 7117 6686 6363 6941 7456 6670 7093 6770 6896 6709 7250 6417 7119 7543 7288
# 3408 1790 2702 3211 2006 1758 3110 3533 2793 2278 3032 2698 1634 2591 2499 1864 3307 3187 2185 3211 2455 3054 1854 2876 3187 3250 3359 2609 3514
# 4844 5743 5796 5353 4480 4998 6088 5068 5884 5902 4307 4227 5632 5492 4746 5038 5015 4372 5699 4932 4470 4874 5964 4794 4849 5883 6033 6159 4985
# ...

# %%
!
