# %%
import re
import sys
from time import sleep
from pprint import pprint
from functools import partial

import numpy as np
import optuna
try:
    import pandas as pd
except:
    pass


FILENAME = "main.cpp"

# %%
SEED = 0
N_TESTCASES = 200
# !seq {SEED} {SEED+N_TESTCASES-1} > seeds.txt && cargo run --release --manifest-path ../tools/Cargo.toml --bin gen seeds.txt
# !ls in
# Out:
# 0000.txt  0025.txt  0050.txt  0075.txt	0100.txt  0125.txt  0150.txt  0175.txt
# 0001.txt  0026.txt  0051.txt  0076.txt	0101.txt  0126.txt  0151.txt  0176.txt
# 0002.txt  0027.txt  0052.txt  0077.txt	0102.txt  0127.txt  0152.txt  0177.txt
# 0003.txt  0028.txt  0053.txt  0078.txt	0103.txt  0128.txt  0153.txt  0178.txt
# 0004.txt  0029.txt  0054.txt  0079.txt	0104.txt  0129.txt  0154.txt  0179.txt
# 0005.txt  0030.txt  0055.txt  0080.txt	0105.txt  0130.txt  0155.txt  0180.txt
# 0006.txt  0031.txt  0056.txt  0081.txt	0106.txt  0131.txt  0156.txt  0181.txt
# 0007.txt  0032.txt  0057.txt  0082.txt	0107.txt  0132.txt  0157.txt  0182.txt
# 0008.txt  0033.txt  0058.txt  0083.txt	0108.txt  0133.txt  0158.txt  0183.txt
# 0009.txt  0034.txt  0059.txt  0084.txt	0109.txt  0134.txt  0159.txt  0184.txt
# 0010.txt  0035.txt  0060.txt  0085.txt	0110.txt  0135.txt  0160.txt  0185.txt
# 0011.txt  0036.txt  0061.txt  0086.txt	0111.txt  0136.txt  0161.txt  0186.txt
# 0012.txt  0037.txt  0062.txt  0087.txt	0112.txt  0137.txt  0162.txt  0187.txt
# 0013.txt  0038.txt  0063.txt  0088.txt	0113.txt  0138.txt  0163.txt  0188.txt
# 0014.txt  0039.txt  0064.txt  0089.txt	0114.txt  0139.txt  0164.txt  0189.txt
# 0015.txt  0040.txt  0065.txt  0090.txt	0115.txt  0140.txt  0165.txt  0190.txt
# 0016.txt  0041.txt  0066.txt  0091.txt	0116.txt  0141.txt  0166.txt  0191.txt
# 0017.txt  0042.txt  0067.txt  0092.txt	0117.txt  0142.txt  0167.txt  0192.txt
# 0018.txt  0043.txt  0068.txt  0093.txt	0118.txt  0143.txt  0168.txt  0193.txt
# 0019.txt  0044.txt  0069.txt  0094.txt	0119.txt  0144.txt  0169.txt  0194.txt
# 0020.txt  0045.txt  0070.txt  0095.txt	0120.txt  0145.txt  0170.txt  0195.txt
# 0021.txt  0046.txt  0071.txt  0096.txt	0121.txt  0146.txt  0171.txt  0196.txt
# 0022.txt  0047.txt  0072.txt  0097.txt	0122.txt  0147.txt  0172.txt  0197.txt
# 0023.txt  0048.txt  0073.txt  0098.txt	0123.txt  0148.txt  0173.txt  0198.txt
# 0024.txt  0049.txt  0074.txt  0099.txt	0124.txt  0149.txt  0174.txt  0199.txt

# %%
# !cp ../main.cpp ./

# %%
# !g++ {FILENAME} -std=gnu++17 -Wall -Wextra -O2 -DONLINE_JUDGE -o {FILENAME}.out
# Out:
# main.cpp:457: warning: ignoring #pragma warning  [-Wunknown-pragmas]
#   457 | #pragma warning( disable : 4146 )
#       |
# main.cpp: In member function ‘void UltimateEstimator::Step()’:
# main.cpp:1147:39: warning: comparison of integer expressions of different signedness: ‘signed char’ and ‘std::array<double, 60>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#  1147 |   for (auto col = (signed char)0; col < data_x.size(); col++) {
#       |                                   ~~~~^~~~~~~~~~~~~~~
# main.cpp:1105:8: warning: unused variable ‘estimated_distance’ [-Wunused-variable]
#  1105 |   auto estimated_distance = 0.0;
#       |        ^~~~~~~~~~~~~~~~~~
# main.cpp: In member function ‘void Explorer::Step()’:
# main.cpp:1375:30: warning: narrowing conversion of ‘(((int)v.Explorer::Node::y) + 1)’ from ‘int’ to ‘signed char’ [-Wnarrowing]
#  1375 |     const auto u = Node{ v.y + (i8)1, v.x, false };
#       |                          ~~~~^~~~~~~
# main.cpp:1388:35: warning: narrowing conversion of ‘(((int)v.Explorer::Node::x) + 1)’ from ‘int’ to ‘signed char’ [-Wnarrowing]
#  1388 |     const auto u = Node{ v.y, v.x + (i8)1, true };
#       |                               ~~~~^~~~~~~
# main.cpp:1401:30: warning: narrowing conversion of ‘(((int)v.Explorer::Node::y) - 1)’ from ‘int’ to ‘signed char’ [-Wnarrowing]
#  1401 |     const auto u = Node{ v.y - (i8)1, v.x, false };
#       |                          ~~~~^~~~~~~
# main.cpp:1414:35: warning: narrowing conversion of ‘(((int)v.Explorer::Node::x) - 1)’ from ‘int’ to ‘signed char’ [-Wnarrowing]
#  1414 |     const auto u = Node{ v.y, v.x - (i8)1, true };
#       |                               ~~~~^~~~~~~
# main.cpp: In function ‘void Experiment::PrintNewData()’:
# main.cpp:69:25: warning: unnecessary parentheses in declaration of ‘q’ [-Wparentheses]
#    69 | #define rep(i,n) for(ll (i)=0; (i)<(n); (i)++)
#       |                         ^
# main.cpp:1766:3: note: in expansion of macro ‘rep’
#  1766 |   rep(q, 1000) {
#       |   ^~~
# main.cpp: In function ‘void Test::lasso_test()’:
# main.cpp:1811:22: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::array<std::array<double, 5>, 6>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#  1811 |   for (auto i = 0; i < X.size(); i++) {
#       |                    ~~^~~~~~~~~~
# main.cpp: In function ‘int main(int, char**)’:
# main.cpp:1822:14: warning: unused parameter ‘argc’ [-Wunused-parameter]
#  1822 | int main(int argc, char* argv[]) {
#       |          ~~~~^~~~
# main.cpp:1822:26: warning: unused parameter ‘argv’ [-Wunused-parameter]
#  1822 | int main(int argc, char* argv[]) {
#       |                    ~~~~~~^~~~~~

# %%
# %%time
# もとのスコアの確認
scores = []
for i in range(200, 1000):
    i = f"{i:04d}"
    score = !cargo run --release --manifest-path ../tools/Cargo.toml --bin tester ../exp004_ultimate/in/{i}.txt $(pwd)/{FILENAME}.out 2>&1 | grep Score
    print(i, *score)
    score = int(score[0].split()[-1])
    scores.append(score)
np.mean(scores) / 1e6, np.std(scores) / 1e6
# Out:
# 0200 Score = 967819637
# 0201 Score = 976768155
# 0202 Score = 979520882
# 0203 Score = 974364345
# 0204 Score = 981574183
# 0205 Score = 971699616
# 0206 Score = 971437848
# 0207 Score = 964041856
# 0208 Score = 976685277
# 0209 Score = 967382261
# 0931 Score = 957738227
# 0932 Score = 985634298
# 0933 Score = 964795317
# 0934 Score = 972064124
# 0935 Score = 973823892
# 0936 Score = 976755931
# 0937 Score = 976720132
# 0938 Score = 968894923
# 0939 Score = 954703872
# 0940 Score = 979839801
# 0941 Score = 979291320
# 0942 Score = 967992432
# 0943 Score = 979378006
# 0944 Score = 981072547
# 0945 Score = 958520980
# 0946 Score = 968360800
# 0947 Score = 958524315
# 0948 Score = 954157989
# 0949 Score = 959600413
# 0950 Score = 963290102
# 0951 Score = 969033408
# 0952 Score = 969843048
# 0953 Score = 985964327
# 0954 Score = 982182625
# 0955 Score = 970292986
# 0956 Score = 974973037
# 0957 Score = 963573583
# 0958 Score = 983893988
# 0959 Score = 977358397
# 0960 Score = 967938875
# 0961 Score = 985937650
# 0962 Score = 962939411
# 0963 Score = 969106382
# 0964 Score = 968284476
# 0965 Score = 979827360
# 0966 Score = 979871158
# 0967 Score = 972314401
# 0968 Score = 957806354
# 0969 Score = 966476612
# 0970 Score = 961610666
# 0971 Score = 956077694
# 0972 Score = 961242271
# 0973 Score = 970054411
# 0974 Score = 978976667
# 0975 Score = 975930766
# 0976 Score = 977477282
# 0977 Score = 958007094
# 0978 Score = 984793332
# 0979 Score = 977293727
# 0980 Score = 972004379
# 0981 Score = 959024934
# 0982 Score = 970170615
# 0983 Score = 976732089
# 0984 Score = 977546270
# 0985 Score = 958220977
# 0986 Score = 974673390
# 0987 Score = 970068993
# 0988 Score = 981167382
# 0989 Score = 973864304
# 0990 Score = 969125427
# 0991 Score = 977740747
# 0992 Score = 965732925
# 0993 Score = 963912291
# 0994 Score = 969883113
# 0995 Score = 966808872
# 0996 Score = 969426306
# 0997 Score = 984137892
# 0998 Score = 960476537
# 0999 Score = 971684077
# CPU times: user 2.13 s, sys: 3.43 s, total: 5.56 s
# Wall time: 13min 34s
# (971.09609432875, 9.347464001440587)

# %%
# 分散増えた

# %%
#!cargo run --release --manifest-path ../tools/Cargo.toml --bin tester ../exp004_ultimate/in/0229.txt $(pwd)/{FILENAME}.out 2>&1

# %%
# !cargo run --release --manifest-path ../tools/Cargo.toml --bin tester in/0000.txt $(pwd)/{FILENAME}.out 2>&1 | grep Score | sed -E s/[^0-9]+//
# Out:
# 975799619

# %%
# ここでエラー出力は何かおかしいかもしれない


# パラメータ抽出
with open(FILENAME) as f:
    answer = f.read()


variables_optimize = []

for left, value, right, options in re.findall(r"^([^/\n]*=\s*)(.+?)(\s*;\s*//(?:.*\W)?OPTIMIZE(\W.*))$", answer, re.MULTILINE):
    name = left.replace("=", "").strip().split()[-1]
    
    searched = re.search(r".*\[(?P<min>.*),(?P<max>.*)\].*", options)
    if searched:
        min_value = max_value = None
        try:
            min_value = eval(searched.group("min"))
            max_value = eval(searched.group("max"))
            assert min_value <= max_value
        except Exception as e:
            print(f"searched={searched}", file=sys.stderr)
            print(e, file=sys.stderr)
            continue
        log = "LOG" in options  # 雑、直したほうが良い
        if type(min_value) != type(max_value):
            print(f"searched={searched}", file=sys.stderr)
            print("types not matched", file=sys.stderr)
            continue
        if isinstance(min_value, int):
            method = "suggest_int"
        elif isinstance(min_value, float):
            method = "suggest_float"
        else:
            print(f"searched={searched}", file=sys.stderr)
            print(f"unknown type ({type(min_value)})", file=sys.stderr)
            continue
        variables_optimize.append({
            "name": name,
            "method": method,
            "min": min_value,
            "max": max_value,
            "log": log,
            "left": left,
            "right": right,
        })
    elif searched := re.search(r".*\{(?P<choices>.*?)\}.*", options):
        choices = list(map(lambda x: x.strip(), searched.group("choices").split(",")))
        variables_optimize.append({
            "name": name,
            "method": "suggest_categorical",
            "choices": choices,
            "left": left,
            "right": right,
        })
    else:
        print(f"searched={searched}", file=sys.stderr)
        print(f"pattern was matched but options are incorrect.", file=sys.stderr)

print(len(variables_optimize), "variables were found.")
if globals().get("pd"):
    display(pd.DataFrame(variables_optimize))
else:
    pprint(variables_optimize)
# Out:
# 7 variables were found.
#                     name         method       min        max    log  \
# 0                 LAMBDA  suggest_float     2.000     1000.0   True
# 1           LASSO_LAMBDA  suggest_float  1000.000  1000000.0   True
# 2          RIDGE2_LAMBDA  suggest_float     1.000   100000.0   True
# 3              UCB1_COEF  suggest_float     1.000    10000.0   True
# 4               UCB1_EPS  suggest_float     0.001       10.0   True
# 5    TURNING_COST_AT_100  suggest_float   100.000   100000.0  False
# 6  TURNING_COST_COEF_TMP  suggest_float     0.001        0.1   True
#
#                                         left  \
# 0                 constexpr double LAMBDA =
# 1           constexpr double LASSO_LAMBDA =
# 2          constexpr double RIDGE2_LAMBDA =
# 3              constexpr double UCB1_COEF =
# 4               constexpr double UCB1_EPS =
# 5    constexpr double TURNING_COST_AT_100 =
# 6  constexpr double TURNING_COST_COEF_TMP =
#
#                                          right
# 0       ;           // OPTIMIZE [2.0, 1e3] LOG
# 1            ;      // OPTIMIZE [1e3, 1e6] LOG
# 2  ;                // OPTIMIZE [1e0, 1e5] LOG
# 3           ;       // OPTIMIZE [1e0, 1e4] LOG
# 4       ;          // OPTIMIZE [1e-3, 1e1] LOG
# 5         ;           // OPTIMIZE [100.0, 1e5]
# 6     ;           // OPTIMIZE [0.001, 0.1] LOG

# %%
def escape(string):  # 正規表現の中でそのまま使いたい文字列をエスケープ
    res = !echo '{string}' | sed -e 's/[]\/$*.^[]/\\&/g'
    return res[0]

def escape_sed(string):  # sed の置換後の文字列用のエスケープ
    res = !echo '{string}' | sed -e 's/[\/&]/\\&/g'
    return res[0]


def objective_with_index(trial, n_internal_parallel):
    index_parallel = trial.number % 10  # これ変数にする
    print(f"{index_parallel=}")
    
    parameters_changed_filename = f"{index_parallel}_{FILENAME}"
    directory_input = "./in"  # "/" をつけない
    
    # !mkdir {index_parallel}_out
    # !mkdir {index_parallel}_score
    # !rm {index_parallel}_out/*
    # !rm {index_parallel}_score/*
    
    # ファイル作成
    # !cp {FILENAME} {parameters_changed_filename}
    sed_options = [f"-i {parameters_changed_filename}"]
    for variable in variables_optimize:
        if variable["method"] == "suggest_categorical":
            val =  trial.suggest_categorical(variable["name"], variable["choices"])
        else:
            val = getattr(trial, variable["method"])(variable["name"], variable["min"], variable["max"])
        left = variable["left"]
        right = variable["right"]
        sed_options.append(f"""-e 's/^{escape(left)}.*{escape(right)}$/{escape_sed(left)}{val}{escape_sed(right)}/'""")
    command_sed = f"sed {' '.join(sed_options)}"
    print(command_sed)
    # !{command_sed}
    
    # コンパイル
    command_compile = f"g++ {parameters_changed_filename} -std=gnu++17 -O2 -DONLINE_JUDGE -o {parameters_changed_filename}.out 2> /dev/null"
    print(command_compile)
    # !{command_compile}
    # 実行・採点コマンド (@ はファイル名)
    command_exec = (
        f"cargo run --release --manifest-path ../tools/Cargo.toml --bin tester {directory_input}/@ $(pwd)/{parameters_changed_filename}.out 2>&1 | grep Score | sed -E s/[^0-9]+// > ./{index_parallel}_score/@;"
        #f"./{parameters_changed_filename}.out < {directory_input}/@ > ./{index_parallel}_out/@;"
        #f"cargo run --release --manifest-path ./tools/Cargo.toml --bin vis {directory_input}/@ ./{index_parallel}_out/@ 2> /dev/null > ./{index_parallel}_score/@;"
    )
    # 並列実行 (sed はパスのディレクトリ部分を消してファイル名にしてる)
    # !find {directory_input}/* | sed 's!^.*/!!' | xargs -I@ -P {n_internal_parallel} sh -c '{command_exec}'
    
    # 集計
    file_paths = !find ./{index_parallel}_score/*
    sum_score = 0
    for file_path in file_paths:  
        with open(file_path) as f:
            sum_score += int(f.read())
    return sum_score

# %%
storage_path = f"study.db"
storage = f"sqlite:///{storage_path}"
study_name = "study"
study = optuna.create_study(storage=storage, load_if_exists=True, study_name=study_name, direction="maximize")

def callback(study, trial):
    try:
        if study.best_value == trial.value:
            print(f"Updated! {study.best_value}")
            index_parallel = trial.number % 10
            parameters_changed_filename = f"{index_parallel}_{FILENAME}"
            # !cp {parameters_changed_filename} 00000optimized.cpp
        print("callback ok")
    except:
        print(":(")

objective = partial(objective_with_index, n_internal_parallel=4)
study.optimize(objective, n_trials=3000, timeout=86400, n_jobs=4, callbacks=[callback])
# Out:
# [I 2021-05-29 06:51:48,909] A new study created in RDB with name: study
# index_parallel=0
# index_parallel=1
# index_parallel=2
# index_parallel=3
# /home/nagis/anaconda3/lib/python3.8/site-packages/optuna/study.py:393: FutureWarning: `n_jobs` argument has been deprecated in v2.7.0. This feature will be removed in v4.0.0. See https://github.com/optuna/optuna/releases/tag/v2.7.0.
#   warnings.warn(
# rm: cannot remove '1_out/*': No such file or directory
# rm: cannot remove '0_out/*': No such file or directory
# rm: cannot remove '2_out/*': No such file or directory
# rm: cannot remove '3_out/*': No such file or directory
# rm: cannot remove '1_score/*': No such file or directory
# rm: cannot remove '0_score/*': No such file or directory
# rm: cannot remove '2_score/*': No such file or directory
# rm: cannot remove '3_score/*': No such file or directory
# sed -i 0_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 779.2892040300311;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 728711.8066511801;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 96762.20681533904;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 6799.634599697234;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 2.819351287714672;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 8923.240851862583;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.03445497441800882;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# sed -i 1_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 665.6014650116966;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 15305.289036500886;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 52730.27107950384;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 3874.0654852789567;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 5.4446417197430925;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 23557.42799401735;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.06436376758068875;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# sed -i 3_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 421.45770966788007;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 852142.137851834;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 78742.11338487251;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 682.0101896363745;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 5.3492374656330055;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 37571.778114156274;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.06888237321779968;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# g++ 0_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 0_main.cpp.out 2> /dev/null
# sed -i 2_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 896.9963894487867;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 240135.3899491775;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 26218.28529925024;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 8397.510312058379;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 0.982688701798887;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 64115.763557557846;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.0728313327220805;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# g++ 1_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 1_main.cpp.out 2> /dev/null
# g++ 3_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 3_main.cpp.out 2> /dev/null
# g++ 2_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 2_main.cpp.out 2> /dev/null
# [I 2021-05-29 06:53:29,173] Trial 3 finished with value: 187524748741.0 and parameters: {'LAMBDA': 421.45770966788007, 'LASSO_LAMBDA': 852142.137851834, 'RIDGE2_LAMBDA': 78742.11338487251, 'UCB1_COEF': 682.0101896363745, 'UCB1_EPS': 5.3492374656330055, 'TURNING_COST_AT_100': 37571.778114156274, 'TURNING_COST_COEF_TMP': 0.06888237321779968}. Best is trial 3 with value: 187524748741.0.
# Updated! 187524748741.0
# callback ok
# index_parallel=4
# rm: cannot remove '4_out/*': No such file or directory
# rm: cannot remove '4_score/*': No such file or directory
# sed -i 4_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 652.6194343725338;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 536226.1821551973;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 70547.24189674377;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 3395.7741994725693;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 4.596298760083409;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 463.2046830540076;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.06155733313948443;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# g++ 4_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 4_main.cpp.out 2> /dev/null
# [I 2021-05-29 06:53:32,701] Trial 2 finished with value: 179005324432.0 and parameters: {'LAMBDA': 896.9963894487867, 'LASSO_LAMBDA': 240135.3899491775, 'RIDGE2_LAMBDA': 26218.28529925024, 'UCB1_COEF': 8397.510312058379, 'UCB1_EPS': 0.982688701798887, 'TURNING_COST_AT_100': 64115.763557557846, 'TURNING_COST_COEF_TMP': 0.0728313327220805}. Best is trial 3 with value: 187524748741.0.
# callback ok
# index_parallel=5
# [I 2021-05-29 06:53:32,778] Trial 0 finished with value: 184271733048.0 and parameters: {'LAMBDA': 779.2892040300311, 'LASSO_LAMBDA': 728711.8066511801, 'RIDGE2_LAMBDA': 96762.20681533904, 'UCB1_COEF': 6799.634599697234, 'UCB1_EPS': 2.819351287714672, 'TURNING_COST_AT_100': 8923.240851862583, 'TURNING_COST_COEF_TMP': 0.03445497441800882}. Best is trial 3 with value: 187524748741.0.
# callback ok
# index_parallel=6
# rm: cannot remove '5_out/*': No such file or directory
# rm: cannot remove '6_out/*': No such file or directory
# rm: cannot remove '5_score/*': No such file or directory
# rm: cannot remove '6_score/*': No such file or directory
# sed -i 5_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 699.4771891600129;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 456650.36221790087;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 10964.42509999018;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 5268.123313133518;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 6.224635527805104;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 12843.307076015251;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.09112256340522693;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# sed -i 6_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 423.78049646137333;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 591187.8595135682;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 28064.6076790968;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 9561.021195638286;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 0.7028942451042002;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 13680.325536269032;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.030554038310937816;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# g++ 5_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 5_main.cpp.out 2> /dev/null
# g++ 6_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 6_main.cpp.out 2> /dev/null
# [I 2021-05-29 06:53:35,527] Trial 1 finished with value: 192472013357.0 and parameters: {'LAMBDA': 665.6014650116966, 'LASSO_LAMBDA': 15305.289036500886, 'RIDGE2_LAMBDA': 52730.27107950384, 'UCB1_COEF': 3874.0654852789567, 'UCB1_EPS': 5.4446417197430925, 'TURNING_COST_AT_100': 23557.42799401735, 'TURNING_COST_COEF_TMP': 0.06436376758068875}. Best is trial 1 with value: 192472013357.0.
# Updated! 192472013357.0
# callback ok
# index_parallel=7
# rm: cannot remove '7_out/*': No such file or directory
# rm: cannot remove '7_score/*': No such file or directory
# sed -i 7_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 546.9142652092862;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 476079.58085842483;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 6724.878922885638;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 9979.748267746478;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 9.464042041497851;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 79530.82286011685;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.05517746952395935;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# g++ 7_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 7_main.cpp.out 2> /dev/null
# [I 2021-05-29 06:55:09,945] Trial 4 finished with value: 187603951317.0 and parameters: {'LAMBDA': 652.6194343725338, 'LASSO_LAMBDA': 536226.1821551973, 'RIDGE2_LAMBDA': 70547.24189674377, 'UCB1_COEF': 3395.7741994725693, 'UCB1_EPS': 4.596298760083409, 'TURNING_COST_AT_100': 463.2046830540076, 'TURNING_COST_COEF_TMP': 0.06155733313948443}. Best is trial 1 with value: 192472013357.0.
# callback ok
# index_parallel=8
# rm: cannot remove '8_out/*': No such file or directory
# rm: cannot remove '8_score/*': No such file or directory
# sed -i 8_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 210.20340117787583;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 443602.4727488195;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 40677.535796537166;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 9574.636286308034;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 2.156098807466576;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 81208.06326700692;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.09634160641681781;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# g++ 8_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 8_main.cpp.out 2> /dev/null
# [I 2021-05-29 06:55:12,439] Trial 6 finished with value: 173376875156.0 and parameters: {'LAMBDA': 423.78049646137333, 'LASSO_LAMBDA': 591187.8595135682, 'RIDGE2_LAMBDA': 28064.6076790968, 'UCB1_COEF': 9561.021195638286, 'UCB1_EPS': 0.7028942451042002, 'TURNING_COST_AT_100': 13680.325536269032, 'TURNING_COST_COEF_TMP': 0.030554038310937816}. Best is trial 1 with value: 192472013357.0.
# callback ok
# index_parallel=9
# rm: cannot remove '9_out/*': No such file or directory
# rm: cannot remove '9_score/*': No such file or directory
# sed -i 9_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 879.2836038309774;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 640080.5337800595;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 91882.52610824208;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 7550.134954555913;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 2.0467922753151466;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 90849.71597063972;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.047674419122582856;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# g++ 9_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 9_main.cpp.out 2> /dev/null
# [I 2021-05-29 06:55:14,061] Trial 5 finished with value: 188564940196.0 and parameters: {'LAMBDA': 699.4771891600129, 'LASSO_LAMBDA': 456650.36221790087, 'RIDGE2_LAMBDA': 10964.42509999018, 'UCB1_COEF': 5268.123313133518, 'UCB1_EPS': 6.224635527805104, 'TURNING_COST_AT_100': 12843.307076015251, 'TURNING_COST_COEF_TMP': 0.09112256340522693}. Best is trial 1 with value: 192472013357.0.
# callback ok
# index_parallel=0
# mkdir: cannot create directory ‘0_out’: File exists
# mkdir: cannot create directory ‘0_score’: File exists
# rm: cannot remove '0_out/*': No such file or directory
# sed -i 0_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 638.7735506635282;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 970927.3551525502;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 97625.26285767656;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 3476.6874365288245;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 3.7079516360083384;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 82249.35076457328;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.004253723763896654;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# g++ 0_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 0_main.cpp.out 2> /dev/null
# [I 2021-05-29 06:55:16,673] Trial 7 finished with value: 186159439780.0 and parameters: {'LAMBDA': 546.9142652092862, 'LASSO_LAMBDA': 476079.58085842483, 'RIDGE2_LAMBDA': 6724.878922885638, 'UCB1_COEF': 9979.748267746478, 'UCB1_EPS': 9.464042041497851, 'TURNING_COST_AT_100': 79530.82286011685, 'TURNING_COST_COEF_TMP': 0.05517746952395935}. Best is trial 1 with value: 192472013357.0.
# callback ok
# index_parallel=1
# mkdir: cannot create directory ‘1_out’: File exists
# mkdir: cannot create directory ‘1_score’: File exists
# rm: cannot remove '1_out/*': No such file or directory
# sed -i 1_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 589.277953855231;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 210041.8361240213;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 27302.196321740506;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 6554.617506300751;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 9.359756481258678;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 70790.62312805941;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.09837707047193882;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# g++ 1_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 1_main.cpp.out 2> /dev/null
# [I 2021-05-29 06:56:45,491] Trial 10 finished with value: 177139932087.0 and parameters: {'LAMBDA': 638.7735506635282, 'LASSO_LAMBDA': 970927.3551525502, 'RIDGE2_LAMBDA': 97625.26285767656, 'UCB1_COEF': 3476.6874365288245, 'UCB1_EPS': 3.7079516360083384, 'TURNING_COST_AT_100': 82249.35076457328, 'TURNING_COST_COEF_TMP': 0.004253723763896654}. Best is trial 1 with value: 192472013357.0.
# callback ok
# index_parallel=2
# mkdir: cannot create directory ‘2_out’: File exists
# mkdir: cannot create directory ‘2_score’: File exists
# rm: cannot remove '2_out/*': No such file or directory
# sed -i 2_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 784.1171795609237;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 494020.16054945317;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 24649.25822217227;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 250.49687572322125;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 4.122707661069747;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 81708.90932505215;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.03893308239804567;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# g++ 2_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 2_main.cpp.out 2> /dev/null
# [I 2021-05-29 06:56:48,745] Trial 8 finished with value: 177583211285.0 and parameters: {'LAMBDA': 210.20340117787583, 'LASSO_LAMBDA': 443602.4727488195, 'RIDGE2_LAMBDA': 40677.535796537166, 'UCB1_COEF': 9574.636286308034, 'UCB1_EPS': 2.156098807466576, 'TURNING_COST_AT_100': 81208.06326700692, 'TURNING_COST_COEF_TMP': 0.09634160641681781}. Best is trial 1 with value: 192472013357.0.
# callback ok
# index_parallel=3
# mkdir: cannot create directory ‘3_out’: File exists
# mkdir: cannot create directory ‘3_score’: File exists
# rm: cannot remove '3_out/*': No such file or directory
# sed -i 3_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 982.6805795193213;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 21298.00007025769;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 62758.49667324893;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 285.97045259809056;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 7.963099278480366;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 37788.80056257591;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.03585857327235352;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# g++ 3_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 3_main.cpp.out 2> /dev/null
# [I 2021-05-29 06:56:52,834] Trial 9 finished with value: 181690548329.0 and parameters: {'LAMBDA': 879.2836038309774, 'LASSO_LAMBDA': 640080.5337800595, 'RIDGE2_LAMBDA': 91882.52610824208, 'UCB1_COEF': 7550.134954555913, 'UCB1_EPS': 2.0467922753151466, 'TURNING_COST_AT_100': 90849.71597063972, 'TURNING_COST_COEF_TMP': 0.047674419122582856}. Best is trial 1 with value: 192472013357.0.
# callback ok
# index_parallel=4
# mkdir: cannot create directory ‘4_out’: File exists
# mkdir: cannot create directory ‘4_score’: File exists
# rm: cannot remove '4_out/*': No such file or directory
# sed -i 4_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 739.1459967926895;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 46437.08001893759;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 52622.57284543785;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 4823.284136451485;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 6.996516337283829;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 30401.07650797712;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.09911717702513523;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# g++ 4_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 4_main.cpp.out 2> /dev/null
# [I 2021-05-29 06:56:57,687] Trial 11 finished with value: 189775879323.0 and parameters: {'LAMBDA': 589.277953855231, 'LASSO_LAMBDA': 210041.8361240213, 'RIDGE2_LAMBDA': 27302.196321740506, 'UCB1_COEF': 6554.617506300751, 'UCB1_EPS': 9.359756481258678, 'TURNING_COST_AT_100': 70790.62312805941, 'TURNING_COST_COEF_TMP': 0.09837707047193882}. Best is trial 1 with value: 192472013357.0.
# callback ok
# index_parallel=5
# mkdir: cannot create directory ‘5_out’: File exists
# mkdir: cannot create directory ‘5_score’: File exists
# rm: cannot remove '5_out/*': No such file or directory
# sed -i 5_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 228.28111146427284;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 32531.265168093727;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 55902.71787621246;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 5099.7139893993035;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 9.720560867365615;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 39557.98427606014;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.08007600120343596;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# g++ 5_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 5_main.cpp.out 2> /dev/null
# [I 2021-05-29 06:58:20,879] Trial 12 finished with value: 188014422758.0 and parameters: {'LAMBDA': 784.1171795609237, 'LASSO_LAMBDA': 494020.16054945317, 'RIDGE2_LAMBDA': 24649.25822217227, 'UCB1_COEF': 250.49687572322125, 'UCB1_EPS': 4.122707661069747, 'TURNING_COST_AT_100': 81708.90932505215, 'TURNING_COST_COEF_TMP': 0.03893308239804567}. Best is trial 1 with value: 192472013357.0.
# callback ok
# index_parallel=6
# mkdir: cannot create directory ‘6_out’: File exists
# mkdir: cannot create directory ‘6_score’: File exists
# rm: cannot remove '6_out/*': No such file or directory
# sed -i 6_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 243.1752785364618;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 19913.582345635346;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 55076.50008383266;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 4902.675291242737;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 9.665992338738876;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 38590.844018481046;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.08192298260548825;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# g++ 6_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 6_main.cpp.out 2> /dev/null
# [I 2021-05-29 06:58:32,166] Trial 13 finished with value: 193618003070.0 and parameters: {'LAMBDA': 982.6805795193213, 'LASSO_LAMBDA': 21298.00007025769, 'RIDGE2_LAMBDA': 62758.49667324893, 'UCB1_COEF': 285.97045259809056, 'UCB1_EPS': 7.963099278480366, 'TURNING_COST_AT_100': 37788.80056257591, 'TURNING_COST_COEF_TMP': 0.03585857327235352}. Best is trial 13 with value: 193618003070.0.
# Updated! 193618003070.0
# callback ok
# index_parallel=7
# mkdir: cannot create directory ‘7_out’: File exists
# mkdir: cannot create directory ‘7_score’: File exists
# rm: cannot remove '7_out/*': No such file or directory
# sed -i 7_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 980.9981110712297;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 22539.356825422743;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 60481.706641888755;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 1874.747791516309;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 7.522135091770558;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 36298.85137473893;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.012589147705307814;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# g++ 7_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 7_main.cpp.out 2> /dev/null
# [I 2021-05-29 06:58:37,187] Trial 14 finished with value: 192172726681.0 and parameters: {'LAMBDA': 739.1459967926895, 'LASSO_LAMBDA': 46437.08001893759, 'RIDGE2_LAMBDA': 52622.57284543785, 'UCB1_COEF': 4823.284136451485, 'UCB1_EPS': 6.996516337283829, 'TURNING_COST_AT_100': 30401.07650797712, 'TURNING_COST_COEF_TMP': 0.09911717702513523}. Best is trial 13 with value: 193618003070.0.
# callback ok
# index_parallel=8
# mkdir: cannot create directory ‘8_out’: File exists
# mkdir: cannot create directory ‘8_score’: File exists
# rm: cannot remove '8_out/*': No such file or directory
# sed -i 8_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 992.0653080690292;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 17084.02064724412;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 59370.21064426187;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 1660.9524928648466;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 7.5173274542062245;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 46290.452693189975;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.012248190473592373;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# g++ 8_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 8_main.cpp.out 2> /dev/null
# [I 2021-05-29 06:58:42,247] Trial 15 finished with value: 192468167070.0 and parameters: {'LAMBDA': 228.28111146427284, 'LASSO_LAMBDA': 32531.265168093727, 'RIDGE2_LAMBDA': 55902.71787621246, 'UCB1_COEF': 5099.7139893993035, 'UCB1_EPS': 9.720560867365615, 'TURNING_COST_AT_100': 39557.98427606014, 'TURNING_COST_COEF_TMP': 0.08007600120343596}. Best is trial 13 with value: 193618003070.0.
# callback ok
# index_parallel=9
# mkdir: cannot create directory ‘9_out’: File exists
# mkdir: cannot create directory ‘9_score’: File exists
# rm: cannot remove '9_out/*': No such file or directory
# sed -i 9_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 974.2096562038809;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 205065.22424832312;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 68258.91803651111;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 1500.0590483400488;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 7.75328895552086;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 54621.096227401584;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.019269227699220792;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# g++ 9_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 9_main.cpp.out 2> /dev/null
# [I 2021-05-29 07:00:03,275] Trial 16 finished with value: 192434924576.0 and parameters: {'LAMBDA': 243.1752785364618, 'LASSO_LAMBDA': 19913.582345635346, 'RIDGE2_LAMBDA': 55076.50008383266, 'UCB1_COEF': 4902.675291242737, 'UCB1_EPS': 9.665992338738876, 'TURNING_COST_AT_100': 38590.844018481046, 'TURNING_COST_COEF_TMP': 0.08192298260548825}. Best is trial 13 with value: 193618003070.0.
# callback ok
# index_parallel=0
# mkdir: cannot create directory ‘0_out’: File exists
# mkdir: cannot create directory ‘0_score’: File exists
# rm: cannot remove '0_out/*': No such file or directory
# sed -i 0_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 979.8416646507723;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 210307.18415210993;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 70457.31222381875;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 1528.2691910044696;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 7.718852735673936;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 55582.36721966864;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.017537326274653497;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# g++ 0_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 0_main.cpp.out 2> /dev/null
# [I 2021-05-29 07:00:13,709] Trial 17 finished with value: 192983578625.0 and parameters: {'LAMBDA': 980.9981110712297, 'LASSO_LAMBDA': 22539.356825422743, 'RIDGE2_LAMBDA': 60481.706641888755, 'UCB1_COEF': 1874.747791516309, 'UCB1_EPS': 7.522135091770558, 'TURNING_COST_AT_100': 36298.85137473893, 'TURNING_COST_COEF_TMP': 0.012589147705307814}. Best is trial 13 with value: 193618003070.0.
# callback ok
# index_parallel=1
# mkdir: cannot create directory ‘1_out’: File exists
# mkdir: cannot create directory ‘1_score’: File exists
# rm: cannot remove '1_out/*': No such file or directory
# sed -i 1_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 993.8038928687229;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 195315.77221385186;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 71264.72936745762;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 1557.1110196054956;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 7.742500565676171;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 55935.68457058929;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.006870849781307302;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# g++ 1_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 1_main.cpp.out 2> /dev/null
# [I 2021-05-29 07:00:19,203] Trial 18 finished with value: 192555297050.0 and parameters: {'LAMBDA': 992.0653080690292, 'LASSO_LAMBDA': 17084.02064724412, 'RIDGE2_LAMBDA': 59370.21064426187, 'UCB1_COEF': 1660.9524928648466, 'UCB1_EPS': 7.5173274542062245, 'TURNING_COST_AT_100': 46290.452693189975, 'TURNING_COST_COEF_TMP': 0.012248190473592373}. Best is trial 13 with value: 193618003070.0.
# callback ok
# index_parallel=2
# mkdir: cannot create directory ‘2_out’: File exists
# mkdir: cannot create directory ‘2_score’: File exists
# rm: cannot remove '2_out/*': No such file or directory
# sed -i 2_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 967.0662733387226;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 187184.43723661697;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 74748.62264856671;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 1793.3336376833481;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 8.206900361168445;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 57481.74277091697;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.018486230706074303;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# g++ 2_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 2_main.cpp.out 2> /dev/null
# [I 2021-05-29 07:00:20,810] Trial 19 finished with value: 190955405435.0 and parameters: {'LAMBDA': 974.2096562038809, 'LASSO_LAMBDA': 205065.22424832312, 'RIDGE2_LAMBDA': 68258.91803651111, 'UCB1_COEF': 1500.0590483400488, 'UCB1_EPS': 7.75328895552086, 'TURNING_COST_AT_100': 54621.096227401584, 'TURNING_COST_COEF_TMP': 0.019269227699220792}. Best is trial 13 with value: 193618003070.0.
# callback ok
# index_parallel=3
# mkdir: cannot create directory ‘3_out’: File exists
# mkdir: cannot create directory ‘3_score’: File exists
# rm: cannot remove '3_out/*': No such file or directory
# sed -i 3_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 897.7125937339833;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 313989.5190434747;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 83855.43189524999;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 2188.103039095988;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 8.637252037471306;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 53879.3938974402;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.022961751545477714;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# g++ 3_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 3_main.cpp.out 2> /dev/null
# [I 2021-05-29 07:01:47,887] Trial 20 finished with value: 190873793780.0 and parameters: {'LAMBDA': 979.8416646507723, 'LASSO_LAMBDA': 210307.18415210993, 'RIDGE2_LAMBDA': 70457.31222381875, 'UCB1_COEF': 1528.2691910044696, 'UCB1_EPS': 7.718852735673936, 'TURNING_COST_AT_100': 55582.36721966864, 'TURNING_COST_COEF_TMP': 0.017537326274653497}. Best is trial 13 with value: 193618003070.0.
# callback ok
# index_parallel=4
# mkdir: cannot create directory ‘4_out’: File exists
# mkdir: cannot create directory ‘4_score’: File exists
# rm: cannot remove '4_out/*': No such file or directory
# sed -i 4_main.cpp -e 's/^constexpr double LAMBDA = .*;           \/\/ OPTIMIZE \[2\.0, 1e3\] LOG$/constexpr double LAMBDA = 891.2808114184181;           \/\/ OPTIMIZE [2.0, 1e3] LOG/' -e 's/^constexpr double LASSO_LAMBDA = .*;      \/\/ OPTIMIZE \[1e3, 1e6\] LOG$/constexpr double LASSO_LAMBDA = 111501.0097402022;      \/\/ OPTIMIZE [1e3, 1e6] LOG/' -e 's/^constexpr double RIDGE2_LAMBDA = .*;                \/\/ OPTIMIZE \[1e0, 1e5\] LOG$/constexpr double RIDGE2_LAMBDA = 43641.54040968086;                \/\/ OPTIMIZE [1e0, 1e5] LOG/' -e 's/^constexpr double UCB1_COEF = .*;       \/\/ OPTIMIZE \[1e0, 1e4\] LOG$/constexpr double UCB1_COEF = 2152.4177334192145;       \/\/ OPTIMIZE [1e0, 1e4] LOG/' -e 's/^constexpr double UCB1_EPS = .*;          \/\/ OPTIMIZE \[1e-3, 1e1\] LOG$/constexpr double UCB1_EPS = 8.62050220095097;          \/\/ OPTIMIZE [1e-3, 1e1] LOG/' -e 's/^constexpr double TURNING_COST_AT_100 = .*;           \/\/ OPTIMIZE \[100\.0, 1e5\]$/constexpr double TURNING_COST_AT_100 = 47270.253437741936;           \/\/ OPTIMIZE [100.0, 1e5]/' -e 's/^constexpr double TURNING_COST_COEF_TMP = .*;           \/\/ OPTIMIZE \[0\.001, 0\.1\] LOG$/constexpr double TURNING_COST_COEF_TMP = 0.001341182195483447;           \/\/ OPTIMIZE [0.001, 0.1] LOG/'
# g++ 4_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 4_main.cpp.out 2> /dev/null
# [I 2021-05-29 07:01:52,512] Trial 21 finished with value: 188855488443.0 and parameters: {'LAMBDA': 993.8038928687229, 'LASSO_LAMBDA': 195315.77221385186, 'RIDGE2_LAMBDA': 71264.72936745762, 'UCB1_COEF': 1557.1110196054956, 'UCB1_EPS': 7.742500565676171, 'TURNING_COST_AT_100': 55935.68457058929, 'TURNING_COST_COEF_TMP': 0.006870849781307302}. Best is trial 13 with value: 193618003070.0.
# callback ok
# index_parallel=5
# mkdir: cannot create directory ‘5_out’: File exists
# mkdir: cannot create directory ‘5_score’: File exists
# rm: cannot remove '5_out/*': No such file or directory
# ...
# g++ 7_main.cpp -std=gnu++17 -O2 -DONLINE_JUDGE -o 7_main.cpp.out 2> /dev/null
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/optuna/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     102                     if len(futures) >= n_jobs:
# --> 103                         completed, futures = wait(futures, return_when=FIRST_COMPLETED)
#     104                         # Raise if exception occurred in executing the completed futures.
#
# ~/anaconda3/lib/python3.8/concurrent/futures/_base.py in wait(fs, timeout, return_when)
#     304
# --> 305     waiter.event.wait(timeout)
#     306     for f in fs:
#
# ~/anaconda3/lib/python3.8/threading.py in wait(self, timeout)
#     557             if not signaled:
# --> 558                 signaled = self._cond.wait(timeout)
#     559             return signaled
#
# ~/anaconda3/lib/python3.8/threading.py in wait(self, timeout)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-10-523e5077cc14> in <module>
#      17 objective = partial(objective_with_index, n_internal_parallel=4)
# ---> 18 study.optimize(objective, n_trials=3000, timeout=86400, n_jobs=4, callbacks=[callback])
#
# ~/anaconda3/lib/python3.8/site-packages/optuna/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     399
# --> 400         _optimize(
#     401             study=self,
#
# ~/anaconda3/lib/python3.8/site-packages/optuna/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     107
# --> 108                     futures.add(
#     109                         executor.submit(
#
# ~/anaconda3/lib/python3.8/concurrent/futures/_base.py in __exit__(self, exc_type, exc_val, exc_tb)
#     635     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 636         self.shutdown(wait=True)
#     637         return False
#
# ~/anaconda3/lib/python3.8/concurrent/futures/thread.py in shutdown(self, wait)
#     235             for t in self._threads:
# --> 236                 t.join()
#     237     shutdown.__doc__ = _base.Executor.shutdown.__doc__
#
# ~/anaconda3/lib/python3.8/threading.py in join(self, timeout)
#    1010         if timeout is None:
# -> 1011             self._wait_for_tstate_lock()
#    1012         else:
#
# ~/anaconda3/lib/python3.8/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1026             assert self._is_stopped
# -> 1027         elif lock.acquire(block, timeout):
#    1028             lock.release()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2044                         # in the engines. This should return a list of strings.
# -> 2045                         stb = value._render_traceback_()
#    2046                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1169             # (5 blanks lines) where none should be returned.
# -> 1170             return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#    1171         except UnicodeDecodeError:
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in wrapped(*args, **kwargs)
#     315         try:
# --> 316             return f(*args, **kwargs)
#     317         finally:
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in _fixed_getinnerframes(etb, context, tb_offset)
#     349
# --> 350     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#     351     # If the error is at the console, don't build any context, since it would
#
# ~/anaconda3/lib/python3.8/inspect.py in getinnerframes(tb, context)
#    1502     while tb:
# -> 1503         frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#    1504         framelist.append(FrameInfo(*frameinfo))
#
# ~/anaconda3/lib/python3.8/inspect.py in getframeinfo(frame, context)
#    1460
# -> 1461     filename = getsourcefile(frame) or getfile(frame)
#    1462     if context > 0:
#
# ~/anaconda3/lib/python3.8/inspect.py in getsourcefile(object)
#     707     # only return a non-existent filename if the module has a PEP 302 loader
# --> 708     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#     709         return filename
#
# ~/anaconda3/lib/python3.8/inspect.py in getmodule(object, _filename)
#     753             modulesbyfile[f] = modulesbyfile[
# --> 754                 os.path.realpath(f)] = module.__name__
#     755     if file in modulesbyfile:
#
# ~/anaconda3/lib/python3.8/posixpath.py in realpath(filename)
#     390     filename = os.fspath(filename)
# --> 391     path, ok = _joinrealpath(filename[:0], filename, {})
#     392     return abspath(path)
#
# ~/anaconda3/lib/python3.8/posixpath.py in _joinrealpath(path, rest, seen)
#     424         newpath = join(path, name)
# --> 425         if not islink(newpath):
#     426             path = newpath
#
# ~/anaconda3/lib/python3.8/posixpath.py in islink(path)
#     166     try:
# --> 167         st = os.lstat(path)
#     168     except (OSError, ValueError, AttributeError):
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2046                     except Exception:
# -> 2047                         stb = self.InteractiveTB.structured_traceback(etype,
#    2048                                             value, tb, tb_offset=tb_offset)
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1435             self.tb = tb
# -> 1436         return FormattedTB.structured_traceback(
#    1437             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1335             # Verbose modes need a full traceback
# -> 1336             return VerboseTB.structured_traceback(
#    1337                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1192
# -> 1193         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1194                                                                tb_offset)
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1147         head = self.prepare_header(etype, self.long_header)
# -> 1148         records = self.get_records(etb, number_of_lines_of_context, tb_offset)
#    1149
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1184             inspect_error()
# -> 1185             traceback.print_exc(file=self.ostream)
#    1186             info('\nUnfortunately, your original traceback can not be constructed.\n')
#
# ~/anaconda3/lib/python3.8/traceback.py in print_exc(limit, file, chain)
#     162     """Shorthand for 'print_exception(*sys.exc_info(), limit, file)'."""
# --> 163     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#     164
#
# ~/anaconda3/lib/python3.8/traceback.py in print_exception(etype, value, tb, limit, file, chain)
#     102         file = sys.stderr
# --> 103     for line in TracebackException(
#     104             type(value), value, tb, limit=limit).format(chain=chain):
#
# ~/anaconda3/lib/python3.8/traceback.py in __init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, _seen)
#     508         # TODO: locals.
# --> 509         self.stack = StackSummary.extract(
#     510             walk_tb(exc_traceback), limit=limit, lookup_lines=lookup_lines,
#
# ~/anaconda3/lib/python3.8/traceback.py in extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     365             for f in result:
# --> 366                 f.line
#     367         return result
#
# ~/anaconda3/lib/python3.8/traceback.py in line(self)
#     287         if self._line is None:
# --> 288             self._line = linecache.getline(self.filename, self.lineno).strip()
#     289         return self._line
#
# ~/anaconda3/lib/python3.8/linecache.py in getline(filename, lineno, module_globals)
#      15 def getline(filename, lineno, module_globals=None):
# ---> 16     lines = getlines(filename, module_globals)
#      17     if 1 <= lineno <= len(lines):
#
# ~/anaconda3/lib/python3.8/linecache.py in getlines(filename, module_globals)
#      46     try:
# ---> 47         return updatecache(filename, module_globals)
#      48     except MemoryError:
#
# ~/anaconda3/lib/python3.8/linecache.py in updatecache(filename, module_globals)
#     135     try:
# --> 136         with tokenize.open(fullname) as fp:
#     137             lines = fp.readlines()
#
# ~/anaconda3/lib/python3.8/tokenize.py in open(filename)
#     393     try:
# --> 394         encoding, lines = detect_encoding(buffer.readline)
#     395         buffer.seek(0)
#
# ~/anaconda3/lib/python3.8/tokenize.py in detect_encoding(readline)
#     362
# --> 363     first = read_or_stop()
#     364     if first.startswith(BOM_UTF8):
#
# ~/anaconda3/lib/python3.8/tokenize.py in read_or_stop()
#     320         try:
# --> 321             return readline()
#     322         except StopIteration:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2058
#    2059         except KeyboardInterrupt:
# -> 2060             print('\n' + self.get_exception_only(), file=sys.stderr)
#    2061
#    2062     def _showtraceback(self, etype, evalue, stb):
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in get_exception_only(self, exc_tuple)
#    2003         """
#    2004         etype, value, tb = self._get_exc_info(exc_tuple)
# -> 2005         msg = traceback.format_exception_only(etype, value)
#    2006         return ''.join(msg)
#    2007
#
# ~/anaconda3/lib/python3.8/traceback.py in format_exception_only(etype, value)
#     138
#     139     """
# --> 140     return list(TracebackException(etype, value, None).format_exception_only())
#     141
#     142
#
# ~/anaconda3/lib/python3.8/traceback.py in __init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, _seen)
#     522             self.msg = exc_value.msg
#     523         if lookup_lines:
# --> 524             self._load_lines()
#     525
#     526     @classmethod
#
# ~/anaconda3/lib/python3.8/traceback.py in _load_lines(self)
#     534             frame.line
#     535         if self.__context__:
# --> 536             self.__context__._load_lines()
#     537         if self.__cause__:
#     538             self.__cause__._load_lines()
#
# ~/anaconda3/lib/python3.8/traceback.py in _load_lines(self)
#     534             frame.line
#     535         if self.__context__:
# --> 536             self.__context__._load_lines()
#     537         if self.__cause__:
#     538             self.__cause__._load_lines()
#
# ~/anaconda3/lib/python3.8/traceback.py in _load_lines(self)
#     534             frame.line
#     535         if self.__context__:
# --> 536             self.__context__._load_lines()
#     537         if self.__cause__:
#     538             self.__cause__._load_lines()
#
# ~/anaconda3/lib/python3.8/traceback.py in _load_lines(self)
#     532         """Private API. force all lines in the stack to be loaded."""
#     533         for frame in self.stack:
# --> 534             frame.line
#     535         if self.__context__:
#     536             self.__context__._load_lines()
#
# ~/anaconda3/lib/python3.8/traceback.py in line(self)
#     286     def line(self):
#     287         if self._line is None:
# --> 288             self._line = linecache.getline(self.filename, self.lineno).strip()
#     289         return self._line
#     290
#
# ~/anaconda3/lib/python3.8/linecache.py in getline(filename, lineno, module_globals)
#      14
#      15 def getline(filename, lineno, module_globals=None):
# ---> 16     lines = getlines(filename, module_globals)
#      17     if 1 <= lineno <= len(lines):
#      18         return lines[lineno-1]
#
# ~/anaconda3/lib/python3.8/linecache.py in getlines(filename, module_globals)
#      45
#      46     try:
# ---> 47         return updatecache(filename, module_globals)
#      48     except MemoryError:
#      49         clearcache()
#
# ~/anaconda3/lib/python3.8/linecache.py in updatecache(filename, module_globals)
#     134             return []
#     135     try:
# --> 136         with tokenize.open(fullname) as fp:
#     137             lines = fp.readlines()
#     138     except OSError:
#
# ~/anaconda3/lib/python3.8/tokenize.py in open(filename)
#     392     buffer = _builtin_open(filename, 'rb')
#     393     try:
# --> 394         encoding, lines = detect_encoding(buffer.readline)
#     395         buffer.seek(0)
#     396         text = TextIOWrapper(buffer, encoding, line_buffering=True)
#
# ~/anaconda3/lib/python3.8/tokenize.py in detect_encoding(readline)
#     361         return encoding
#     362
# --> 363     first = read_or_stop()
#     364     if first.startswith(BOM_UTF8):
#     365         bom_found = True
#
# ~/anaconda3/lib/python3.8/tokenize.py in read_or_stop()
#     319     def read_or_stop():
#     320         try:
# --> 321             return readline()
#     322         except StopIteration:
#     323             return b''
#
# KeyboardInterrupt:

# %%
print(f"{study.best_value}")
pprint(study.best_params)
# Out:
# 194244477391.0
# {'LAMBDA': 59.489480502205254,
#  'LASSO_LAMBDA': 20200.451393618623,
#  'RIDGE2_LAMBDA': 72631.90303629794,
#  'TURNING_COST_AT_100': 1910.0482839363026,
#  'TURNING_COST_COEF_TMP': 0.017606710126168428,
#  'UCB1_COEF': 650.0181994059643,
#  'UCB1_EPS': 0.47759235878127837}
